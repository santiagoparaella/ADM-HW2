# %% [markdown]
# <h1> RQ3 </h1>

# %%
#import libraries
import pandas as pd
import seaborn as sns
import json
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %%
#read json data into pandas datframe
df_teams = pd.read_json ('/users/poojacj/Desktop/adm_hw2/teams.json')

# %%
df_teams.head(10)
# Out:
#                            city                   name  wyId  \
# 0           Newcastle upon Tyne       Newcastle United  1613
# 1                          Vigo          Celta de Vigo   692
# 2                     Barcelona               Espanyol   691
# 3               Vitoria-Gasteiz  Deportivo Alav\u00e9s   696
# 4                      Valencia                Levante   695
# 5                        Troyes                 Troyes  3795
# 6               Getafe (Madrid)                 Getafe   698
# 7          M\u00f6nchengladbach    Borussia M'gladbach  2454
# 8  Huddersfield, West Yorkshire      Huddersfield Town  1673
# 9                        Bilbao          Athletic Club   678
#
#                                     officialName  \
# 0                            Newcastle United FC
# 1                        Real Club Celta de Vigo
# 2                   Reial Club Deportiu Espanyol
# 3                          Deportivo Alav\u00e9s
# 4                                     Levante UD
# 5  Esp\u00e9rance Sportive Troyes Aube Champagne
# 6                     Getafe Club de F\u00fatbol
# 7              Borussia VfL M\u00f6nchengladbach
# 8                           Huddersfield Town FC
# 9                           Athletic Club Bilbao
#
#                                                 area  type
# 0  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 1  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 2  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 3  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 4  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 5  {'name': 'France', 'id': '250', 'alpha3code': ...  club
# 6  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 7  {'name': 'Germany', 'id': '276', 'alpha3code':...  club
# 8  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 9  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club

# %%
df_teams.shape
# Out:
# (142, 6)

# %%
df_teams.columns.values
# Out:
# array(['city', 'name', 'wyId', 'officialName', 'area', 'type'],
#       dtype=object)

# %%
df_teams.isna().sum()
# Out:
# city            0
# name            0
# wyId            0
# officialName    0
# area            0
# type            0
# dtype: int64

# %%
df_teams.officialName.nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0               Newcastle United FC
# 1           Real Club Celta de Vigo
# 2      Reial Club Deportiu Espanyol
# 3             Deportivo Alav\u00e9s
# 4                        Levante UD
#                    ...
# 137                           Spain
# 138                          Serbia
# 139                     Switzerland
# 140                          Poland
# 141                         Nigeria
# Name: officialName, Length: 142, dtype: object>

# %%
#filter based on the type of team. 
#choose club teams
df_teams = df_teams[df_teams['type'] ==  "club"]

# %%
df_teams[:20]
# Out:
#                             city                   name   wyId  \
# 0            Newcastle upon Tyne       Newcastle United   1613
# 1                           Vigo          Celta de Vigo    692
# 2                      Barcelona               Espanyol    691
# 3                Vitoria-Gasteiz  Deportivo Alav\u00e9s    696
# 4                       Valencia                Levante    695
# 5                         Troyes                 Troyes   3795
# 6                Getafe (Madrid)                 Getafe    698
# 7           M\u00f6nchengladbach    Borussia M'gladbach   2454
# 8   Huddersfield, West Yorkshire      Huddersfield Town   1673
# 9                         Bilbao          Athletic Club    678
# 10                        Madrid   Atl\u00e9tico Madrid    679
# 11                          Lyon     Olympique Lyonnais   3766
# 12                         Paris                    PSG   3767
# 13                      Valencia               Valencia    674
# 14                        Madrid            Real Madrid    675
# 15                     Barcelona              Barcelona    676
# 16    Las Palmas de Gran Canaria             Las Palmas    714
# 17                  Legan\u00e9s           Legan\u00e9s    712
# 18                       Ferrara                   SPAL   3204
# 19                       Swansea           Swansea City  10531
#
#                                      officialName  \
# 0                             Newcastle United FC
# 1                         Real Club Celta de Vigo
# 2                    Reial Club Deportiu Espanyol
# 3                           Deportivo Alav\u00e9s
# 4                                      Levante UD
# 5   Esp\u00e9rance Sportive Troyes Aube Champagne
# 6                      Getafe Club de F\u00fatbol
# 7               Borussia VfL M\u00f6nchengladbach
# 8                            Huddersfield Town FC
# 9                            Athletic Club Bilbao
# 10                   Club Atl\u00e9tico de Madrid
# 11                             Olympique Lyonnais
# 12                         Paris Saint-Germain FC
# 13                   Valencia Club de F\u00fatbol
# 14                Real Madrid Club de F\u00fatbol
# 15                                   FC Barcelona
# 16                                  UD Las Palmas
# 17                                CD Legan\u00e9s
# 18    Societ\u00e0 Polisportiva Ars et Labor 2013
# 19                               Swansea City AFC
#
#                                                  area  type
# 0   {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 1   {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 2   {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 3   {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 4   {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 5   {'name': 'France', 'id': '250', 'alpha3code': ...  club
# 6   {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 7   {'name': 'Germany', 'id': '276', 'alpha3code':...  club
# 8   {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 9   {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 10  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 11  {'name': 'France', 'id': '250', 'alpha3code': ...  club
# 12  {'name': 'France', 'id': '250', 'alpha3code': ...  club
# 13  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 14  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 15  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 16  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 17  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 18  {'name': 'Italy', 'id': '380', 'alpha3code': '...  club
# 19  {'name': 'Wales', 'id': '0', 'alpha3code': 'XW...  club

# %%
#choose the teams in English Premier Leagues (England)
#included Wales because Swansea city AFC is a part of English Premier League
filtered_data = []
for i,x in df_teams['area'].items():
    if (x['name'] == "England") | (x['name'] == "Wales") :
        print(i,x)
        filtered_data.append({'index': i, 'area': x})
# Out:
# 0 {'name': 'England', 'id': '0', 'alpha3code': 'XEN', 'alpha2code': ''}
# 8 {'name': 'England', 'id': '0', 'alpha3code': 'XEN', 'alpha2code': ''}
# 19 {'name': 'Wales', 'id': '0', 'alpha3code': 'XWA', 'alpha2code': ''}
# 26 {'name': 'England', 'id': '0', 'alpha3code': 'XEN', 'alpha2code': ''}
# 27 {'name': 'England', 'id': '0', 'alpha3code': 'XEN', 'alpha2code': ''}
# 39 {'name': 'England', 'id': '0', 'alpha3code': 'XEN', 'alpha2code': ''}
# 54 {'name': 'England', 'id': '0', 'alpha3code': 'XEN', 'alpha2code': ''}
# 55 {'name': 'England', 'id': '0', 'alpha3code': 'XEN', 'alpha2code': ''}
# 56 {'name': 'England', 'id': '0', 'alpha3code': 'XEN', 'alpha2code': ''}
# 60 {'name': 'England', 'id': '0', 'alpha3code': 'XEN', 'alpha2code': ''}
# 65 {'name': 'England', 'id': '0', 'alpha3code': 'XEN', 'alpha2code': ''}
# 66 {'name': 'England', 'id': '0', 'alpha3code': 'XEN', 'alpha2code': ''}
# 67 {'name': 'England', 'id': '0', 'alpha3code': 'XEN', 'alpha2code': ''}
# 68 {'name': 'England', 'id': '0', 'alpha3code': 'XEN', 'alpha2code': ''}
# 70 {'name': 'England', 'id': '0', 'alpha3code': 'XEN', 'alpha2code': ''}
# 75 {'name': 'England', 'id': '0', 'alpha3code': 'XEN', 'alpha2code': ''}
# 77 {'name': 'England', 'id': '0', 'alpha3code': 'XEN', 'alpha2code': ''}
# 78 {'name': 'England', 'id': '0', 'alpha3code': 'XEN', 'alpha2code': ''}
# 79 {'name': 'England', 'id': '0', 'alpha3code': 'XEN', 'alpha2code': ''}
# 84 {'name': 'England', 'id': '0', 'alpha3code': 'XEN', 'alpha2code': ''}

# %%
filtered_data = pd.DataFrame(filtered_data)

# %%
#setting the index 
filtered_data = filtered_data.set_index('index')

# %%
filtered_data
# Out:
#                                                     area
# index
# 0      {'name': 'England', 'id': '0', 'alpha3code': '...
# 8      {'name': 'England', 'id': '0', 'alpha3code': '...
# 19     {'name': 'Wales', 'id': '0', 'alpha3code': 'XW...
# 26     {'name': 'England', 'id': '0', 'alpha3code': '...
# 27     {'name': 'England', 'id': '0', 'alpha3code': '...
# 39     {'name': 'England', 'id': '0', 'alpha3code': '...
# 54     {'name': 'England', 'id': '0', 'alpha3code': '...
# 55     {'name': 'England', 'id': '0', 'alpha3code': '...
# 56     {'name': 'England', 'id': '0', 'alpha3code': '...
# 60     {'name': 'England', 'id': '0', 'alpha3code': '...
# 65     {'name': 'England', 'id': '0', 'alpha3code': '...
# 66     {'name': 'England', 'id': '0', 'alpha3code': '...
# 67     {'name': 'England', 'id': '0', 'alpha3code': '...
# 68     {'name': 'England', 'id': '0', 'alpha3code': '...
# 70     {'name': 'England', 'id': '0', 'alpha3code': '...
# 75     {'name': 'England', 'id': '0', 'alpha3code': '...
# 77     {'name': 'England', 'id': '0', 'alpha3code': '...
# 78     {'name': 'England', 'id': '0', 'alpha3code': '...
# 79     {'name': 'England', 'id': '0', 'alpha3code': '...
# 84     {'name': 'England', 'id': '0', 'alpha3code': '...

# %%
#merge teams and filtered dataframes on index
df_teams = df_teams.merge(filtered_data, left_index=True, right_index=True)

# %%
df_teams
# Out:
#                             city                    name   wyId  \
# 0            Newcastle upon Tyne        Newcastle United   1613
# 8   Huddersfield, West Yorkshire       Huddersfield Town   1673
# 19                       Swansea            Swansea City  10531
# 26           Bournemouth, Dorset         AFC Bournemouth   1659
# 27         Brighton, East Sussex  Brighton & Hove Albion   1651
# 39           Burnley, Lancashire                 Burnley   1646
# 54                     Leicester          Leicester City   1631
# 55                        London         West Ham United   1633
# 56                Stoke-on-Trent              Stoke City   1639
# 60                       Watford                 Watford   1644
# 65                     Liverpool                 Everton   1623
# 66                 West Bromwich    West Bromwich Albion   1627
# 67                    Manchester         Manchester City   1625
# 68                        London       Tottenham Hotspur   1624
# 70                        London          Crystal Palace   1628
# 75        Southampton, Hampshire             Southampton   1619
# 77                     Liverpool               Liverpool   1612
# 78                        London                 Chelsea   1610
# 79                    Manchester       Manchester United   1611
# 84                        London                 Arsenal   1609
#
#                  officialName  \
# 0         Newcastle United FC
# 8        Huddersfield Town FC
# 19           Swansea City AFC
# 26            AFC Bournemouth
# 27  Brighton & Hove Albion FC
# 39                 Burnley FC
# 54          Leicester City FC
# 55         West Ham United FC
# 56              Stoke City FC
# 60                 Watford FC
# 65                 Everton FC
# 66    West Bromwich Albion FC
# 67         Manchester City FC
# 68       Tottenham Hotspur FC
# 70          Crystal Palace FC
# 75             Southampton FC
# 77               Liverpool FC
# 78                 Chelsea FC
# 79       Manchester United FC
# 84                 Arsenal FC
#
#                                                area_x  type  \
# 0   {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 8   {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 19  {'name': 'Wales', 'id': '0', 'alpha3code': 'XW...  club
# 26  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 27  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 39  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 54  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 55  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 56  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 60  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 65  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 66  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 67  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 68  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 70  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 75  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 77  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 78  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 79  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 84  {'name': 'England', 'id': '0', 'alpha3code': '...  club
#
#                                                area_y
# 0   {'name': 'England', 'id': '0', 'alpha3code': '...
# 8   {'name': 'England', 'id': '0', 'alpha3code': '...
# 19  {'name': 'Wales', 'id': '0', 'alpha3code': 'XW...
# 26  {'name': 'England', 'id': '0', 'alpha3code': '...
# 27  {'name': 'England', 'id': '0', 'alpha3code': '...
# 39  {'name': 'England', 'id': '0', 'alpha3code': '...
# 54  {'name': 'England', 'id': '0', 'alpha3code': '...
# 55  {'name': 'England', 'id': '0', 'alpha3code': '...
# 56  {'name': 'England', 'id': '0', 'alpha3code': '...
# 60  {'name': 'England', 'id': '0', 'alpha3code': '...
# 65  {'name': 'England', 'id': '0', 'alpha3code': '...
# 66  {'name': 'England', 'id': '0', 'alpha3code': '...
# 67  {'name': 'England', 'id': '0', 'alpha3code': '...
# 68  {'name': 'England', 'id': '0', 'alpha3code': '...
# 70  {'name': 'England', 'id': '0', 'alpha3code': '...
# 75  {'name': 'England', 'id': '0', 'alpha3code': '...
# 77  {'name': 'England', 'id': '0', 'alpha3code': '...
# 78  {'name': 'England', 'id': '0', 'alpha3code': '...
# 79  {'name': 'England', 'id': '0', 'alpha3code': '...
# 84  {'name': 'England', 'id': '0', 'alpha3code': '...

# %%
#drop unnecessary columns
df_teams = df_teams.drop(['area_x','area_y', 'name', 'type'], axis=1)

# %%
df_teams
# Out:
#                             city   wyId               officialName
# 0            Newcastle upon Tyne   1613        Newcastle United FC
# 8   Huddersfield, West Yorkshire   1673       Huddersfield Town FC
# 19                       Swansea  10531           Swansea City AFC
# 26           Bournemouth, Dorset   1659            AFC Bournemouth
# 27         Brighton, East Sussex   1651  Brighton & Hove Albion FC
# 39           Burnley, Lancashire   1646                 Burnley FC
# 54                     Leicester   1631          Leicester City FC
# 55                        London   1633         West Ham United FC
# 56                Stoke-on-Trent   1639              Stoke City FC
# 60                       Watford   1644                 Watford FC
# 65                     Liverpool   1623                 Everton FC
# 66                 West Bromwich   1627    West Bromwich Albion FC
# 67                    Manchester   1625         Manchester City FC
# 68                        London   1624       Tottenham Hotspur FC
# 70                        London   1628          Crystal Palace FC
# 75        Southampton, Hampshire   1619             Southampton FC
# 77                     Liverpool   1612               Liverpool FC
# 78                        London   1610                 Chelsea FC
# 79                    Manchester   1611       Manchester United FC
# 84                        London   1609                 Arsenal FC

# %%
#rename the column names
df_teams.columns = ['city','currentTeamId','officialName']

# %%
df_teams
# Out:
#                             city  currentTeamId               officialName
# 0            Newcastle upon Tyne           1613        Newcastle United FC
# 8   Huddersfield, West Yorkshire           1673       Huddersfield Town FC
# 19                       Swansea          10531           Swansea City AFC
# 26           Bournemouth, Dorset           1659            AFC Bournemouth
# 27         Brighton, East Sussex           1651  Brighton & Hove Albion FC
# 39           Burnley, Lancashire           1646                 Burnley FC
# 54                     Leicester           1631          Leicester City FC
# 55                        London           1633         West Ham United FC
# 56                Stoke-on-Trent           1639              Stoke City FC
# 60                       Watford           1644                 Watford FC
# 65                     Liverpool           1623                 Everton FC
# 66                 West Bromwich           1627    West Bromwich Albion FC
# 67                    Manchester           1625         Manchester City FC
# 68                        London           1624       Tottenham Hotspur FC
# 70                        London           1628          Crystal Palace FC
# 75        Southampton, Hampshire           1619             Southampton FC
# 77                     Liverpool           1612               Liverpool FC
# 78                        London           1610                 Chelsea FC
# 79                    Manchester           1611       Manchester United FC
# 84                        London           1609                 Arsenal FC

# %%
#read json data into pandas datframe
df_coaches = pd.read_json('/users/poojacj/Desktop/adm_hw2/coaches.json')

# %%
df_coaches.head(10)
# Out:
#      wyId         shortName        firstName middleName          lastName  \
# 0  275580     Cesar Domingo    César Domingo              Mendiondo López
# 1   14710       J. Heynckes            Josef                     Heynckes
# 2  135480       G. De Biasi         Giovanni                     De Biasi
# 3  210074         Marcelino        Marcelino                 García Toral
# 4  293398         T. Korkut           Tayfun                       Korkut
# 5   92894  Ernesto Valverde          Ernesto             Valverde Tejedor
# 6    3880             Unzué      Juan Carlos                Unzué Labiano
# 7   17121       D. Schuster             Dirk                     Schuster
# 8   20454          A. Conte          Antonio                        Conte
# 9   86604         R. Gareca  Ricardo Alberto                 Gareca Nardi
#
#     birthDate                                          birthArea  \
# 0        None  {'id': 76, 'alpha2code': 'BR', 'alpha3code': '...
# 1  1945-05-09  {'id': 276, 'alpha2code': 'DE', 'alpha3code': ...
# 2  1956-06-16  {'id': 380, 'alpha2code': 'IT', 'alpha3code': ...
# 3  1965-08-14  {'id': 724, 'alpha2code': 'ES', 'alpha3code': ...
# 4  1974-04-02  {'id': 276, 'alpha2code': 'DE', 'alpha3code': ...
# 5  1964-02-09  {'id': 724, 'alpha2code': 'ES', 'alpha3code': ...
# 6  1967-04-22  {'id': 724, 'alpha2code': 'ES', 'alpha3code': ...
# 7  1967-12-29  {'id': 276, 'alpha2code': 'DE', 'alpha3code': ...
# 8  1969-07-31  {'id': 380, 'alpha2code': 'IT', 'alpha3code': ...
# 9  1958-02-10  {'id': 32, 'alpha2code': 'AR', 'alpha3code': '...
#
#                                         passportArea  currentTeamId
# 0  {'id': 76, 'alpha2code': 'BR', 'alpha3code': '...              0
# 1  {'id': 276, 'alpha2code': 'DE', 'alpha3code': ...              0
# 2  {'id': 380, 'alpha2code': 'IT', 'alpha3code': ...              0
# 3  {'id': 724, 'alpha2code': 'ES', 'alpha3code': ...            674
# 4  {'id': 792, 'alpha2code': 'TR', 'alpha3code': ...              0
# 5  {'id': 724, 'alpha2code': 'ES', 'alpha3code': ...            676
# 6  {'id': 724, 'alpha2code': 'ES', 'alpha3code': ...              0
# 7  {'id': 276, 'alpha2code': 'DE', 'alpha3code': ...              0
# 8  {'id': 380, 'alpha2code': 'IT', 'alpha3code': ...              0
# 9  {'id': 32, 'alpha2code': 'AR', 'alpha3code': '...              0

# %%
df_coaches.shape
# Out:
# (208, 9)

# %%
df_coaches.columns.values
# Out:
# array(['wyId', 'shortName', 'firstName', 'middleName', 'lastName',
#        'birthDate', 'birthArea', 'passportArea', 'currentTeamId'],
#       dtype=object)

# %%
df_coaches.isna().sum()
# Out:
# wyId             0
# shortName        0
# firstName        0
# middleName       0
# lastName         0
# birthDate        2
# birthArea        0
# passportArea     0
# currentTeamId    0
# dtype: int64

# %%
df_coaches.shape
# Out:
# (208, 9)

# %%
#drop unnecessary columns
df_coaches = df_coaches.drop(['birthArea', 'passportArea'], axis=1)

# %%
df_coaches.head(10)
# Out:
#      wyId         shortName        firstName middleName          lastName  \
# 0  275580     Cesar Domingo    César Domingo              Mendiondo López
# 1   14710       J. Heynckes            Josef                     Heynckes
# 2  135480       G. De Biasi         Giovanni                     De Biasi
# 3  210074         Marcelino        Marcelino                 García Toral
# 4  293398         T. Korkut           Tayfun                       Korkut
# 5   92894  Ernesto Valverde          Ernesto             Valverde Tejedor
# 6    3880             Unzué      Juan Carlos                Unzué Labiano
# 7   17121       D. Schuster             Dirk                     Schuster
# 8   20454          A. Conte          Antonio                        Conte
# 9   86604         R. Gareca  Ricardo Alberto                 Gareca Nardi
#
#     birthDate  currentTeamId
# 0        None              0
# 1  1945-05-09              0
# 2  1956-06-16              0
# 3  1965-08-14            674
# 4  1974-04-02              0
# 5  1964-02-09            676
# 6  1967-04-22              0
# 7  1967-12-29              0
# 8  1969-07-31              0
# 9  1958-02-10              0

# %%
#left join the teams and coches dataframes on id
df_merge_col = pd.merge(df_teams, df_coaches, on='currentTeamId', how='left')

# %%
df_merge_col.head(10)
# Out:
#                            city  currentTeamId               officialName  \
# 0           Newcastle upon Tyne           1613        Newcastle United FC
# 1           Newcastle upon Tyne           1613        Newcastle United FC
# 2  Huddersfield, West Yorkshire           1673       Huddersfield Town FC
# 3                       Swansea          10531           Swansea City AFC
# 4           Bournemouth, Dorset           1659            AFC Bournemouth
# 5         Brighton, East Sussex           1651  Brighton & Hove Albion FC
# 6           Burnley, Lancashire           1646                 Burnley FC
# 7                     Leicester           1631          Leicester City FC
# 8                        London           1633         West Ham United FC
# 9                Stoke-on-Trent           1639              Stoke City FC
#
#        wyId       shortName  firstName middleName          lastName  \
# 0  210700.0  Rafael Benítez     Rafael               Benítez Maudes
# 1  531745.0            Paco  Francisco             de Míguel Moreno
# 2       NaN             NaN        NaN        NaN               NaN
# 3       NaN             NaN        NaN        NaN               NaN
# 4    8934.0         E. Howe      Eddie                         Howe
# 5    8093.0      C. Hughton      Chris                      Hughton
# 6    8880.0        S. Dyche       Sean                        Dyche
# 7       NaN             NaN        NaN        NaN               NaN
# 8       NaN             NaN        NaN        NaN               NaN
# 9       NaN             NaN        NaN        NaN               NaN
#
#     birthDate
# 0  1960-04-16
# 1  1973-02-19
# 2         NaN
# 3         NaN
# 4  1977-11-29
# 5  1958-12-11
# 6  1971-06-28
# 7         NaN
# 8         NaN
# 9         NaN

# %%
#drop the rows with empty date of birth values
df_merge_col = df_merge_col.dropna(axis = 0, how ='any')

# %%
#convert the birthdate datatype to datetime for calculation of age 
df_merge_col['birthdate_datetime'] = pd.to_datetime(df_merge_col.birthDate, infer_datetime_format=True)

# %%
df_merge_col['birthdate_datetime']
# Out:
# 0    1960-04-16
# 1    1973-02-19
# 4    1977-11-29
# 5    1958-12-11
# 6    1971-06-28
# 10   1970-05-01
# 11   1977-07-12
# 13   1971-01-18
# 14   1972-03-02
# 15   1947-08-09
# 16   1967-08-09
# 17   1967-06-16
# 18   1959-01-10
# 20   1971-11-03
# Name: birthdate_datetime, dtype: datetime64[ns]

# %%
#calculate the age of coaches
df_merge_col['age'] = ((pd.to_datetime('today') - df_merge_col['birthdate_datetime'])/365).dt.days

# %%
df_merge_col['age']
# Out:
# 0     59
# 1     46
# 4     41
# 5     60
# 6     48
# 10    49
# 11    42
# 13    48
# 14    47
# 15    72
# 16    52
# 17    52
# 18    60
# 20    48
# Name: age, dtype: int64

# %%
df_merge_col
# Out:
#                       city  currentTeamId               officialName  \
# 0      Newcastle upon Tyne           1613        Newcastle United FC
# 1      Newcastle upon Tyne           1613        Newcastle United FC
# 4      Bournemouth, Dorset           1659            AFC Bournemouth
# 5    Brighton, East Sussex           1651  Brighton & Hove Albion FC
# 6      Burnley, Lancashire           1646                 Burnley FC
# 10                 Watford           1644                 Watford FC
# 11               Liverpool           1623                 Everton FC
# 13              Manchester           1625         Manchester City FC
# 14                  London           1624       Tottenham Hotspur FC
# 15                  London           1628          Crystal Palace FC
# 16  Southampton, Hampshire           1619             Southampton FC
# 17               Liverpool           1612               Liverpool FC
# 18                  London           1610                 Chelsea FC
# 20                  London           1609                 Arsenal FC
#
#         wyId       shortName         firstName middleName  \
# 0   210700.0  Rafael Benítez            Rafael
# 1   531745.0            Paco         Francisco
# 4     8934.0         E. Howe             Eddie
# 5     8093.0      C. Hughton             Chris
# 6     8880.0        S. Dyche              Sean
# 10   93112.0     Javi Gracia            Javier
# 11   71037.0     Marco Silva   Marco Alexandre
# 13  267136.0       Guardiola            Josep
# 14  292863.0   M. Pochettino  Mauricio Roberto
# 15    8357.0      R. Hodgson               Roy
# 16   15824.0   R. Hasenhüttl             Ralph
# 17   14791.0        J. Klopp            Jürgen
# 18  210252.0        M. Sarri          Maurizio
# 20    3265.0      Unai Emery              Unai
#
#                lastName   birthDate birthdate_datetime  age
# 0        Benítez Maudes  1960-04-16         1960-04-16   59
# 1      de Míguel Moreno  1973-02-19         1973-02-19   46
# 4                  Howe  1977-11-29         1977-11-29   41
# 5               Hughton  1958-12-11         1958-12-11   60
# 6                 Dyche  1971-06-28         1971-06-28   48
# 10        Gracia Carlos  1970-05-01         1970-05-01   49
# 11     Saraiva da Silva  1977-07-12         1977-07-12   42
# 13     Guardiola i Sala  1971-01-18         1971-01-18   48
# 14  Pochettino Trossero  1972-03-02         1972-03-02   47
# 15              Hodgson  1947-08-09         1947-08-09   72
# 16           Hasenhüttl  1967-08-09         1967-08-09   52
# 17                Klopp  1967-06-16         1967-06-16   52
# 18                Sarri  1959-01-10         1959-01-10   60
# 20      Emery Etxegoien  1971-11-03         1971-11-03   48

# %%
#sort the columns in ascending order of age
df_age_sorted = df_merge_col.sort_values(by='age', ascending=True)

# %%
#select the top 10 rows
df_youngest_coaches = df_age_sorted[:10]

# %%
results = df_youngest_coaches[['officialName','shortName','age']]

# %%
results.columns = ['TeamName','CoachName','CoachAge']

# %%
results
# Out:
#                 TeamName      CoachName  CoachAge
# 4        AFC Bournemouth        E. Howe        41
# 11            Everton FC    Marco Silva        42
# 1    Newcastle United FC           Paco        46
# 14  Tottenham Hotspur FC  M. Pochettino        47
# 6             Burnley FC       S. Dyche        48
# 13    Manchester City FC      Guardiola        48
# 20            Arsenal FC     Unai Emery        48
# 10            Watford FC    Javi Gracia        49
# 16        Southampton FC  R. Hasenhüttl        52
# 17          Liverpool FC       J. Klopp        52

# %%
#save the results to a csv file
results.to_csv("/users/poojacj/Desktop/adm_hw2/RQ3/youngest_coaches.csv",index=None)

# %%
df_age_sorted
# Out:
#                       city  currentTeamId               officialName  \
# 4      Bournemouth, Dorset           1659            AFC Bournemouth
# 11               Liverpool           1623                 Everton FC
# 1      Newcastle upon Tyne           1613        Newcastle United FC
# 14                  London           1624       Tottenham Hotspur FC
# 6      Burnley, Lancashire           1646                 Burnley FC
# 13              Manchester           1625         Manchester City FC
# 20                  London           1609                 Arsenal FC
# 10                 Watford           1644                 Watford FC
# 16  Southampton, Hampshire           1619             Southampton FC
# 17               Liverpool           1612               Liverpool FC
# 0      Newcastle upon Tyne           1613        Newcastle United FC
# 5    Brighton, East Sussex           1651  Brighton & Hove Albion FC
# 18                  London           1610                 Chelsea FC
# 15                  London           1628          Crystal Palace FC
#
#         wyId       shortName         firstName middleName  \
# 4     8934.0         E. Howe             Eddie
# 11   71037.0     Marco Silva   Marco Alexandre
# 1   531745.0            Paco         Francisco
# 14  292863.0   M. Pochettino  Mauricio Roberto
# 6     8880.0        S. Dyche              Sean
# 13  267136.0       Guardiola            Josep
# 20    3265.0      Unai Emery              Unai
# 10   93112.0     Javi Gracia            Javier
# 16   15824.0   R. Hasenhüttl             Ralph
# 17   14791.0        J. Klopp            Jürgen
# 0   210700.0  Rafael Benítez            Rafael
# 5     8093.0      C. Hughton             Chris
# 18  210252.0        M. Sarri          Maurizio
# 15    8357.0      R. Hodgson               Roy
#
#                lastName   birthDate birthdate_datetime  age
# 4                  Howe  1977-11-29         1977-11-29   41
# 11     Saraiva da Silva  1977-07-12         1977-07-12   42
# 1      de Míguel Moreno  1973-02-19         1973-02-19   46
# 14  Pochettino Trossero  1972-03-02         1972-03-02   47
# 6                 Dyche  1971-06-28         1971-06-28   48
# 13     Guardiola i Sala  1971-01-18         1971-01-18   48
# 20      Emery Etxegoien  1971-11-03         1971-11-03   48
# 10        Gracia Carlos  1970-05-01         1970-05-01   49
# 16           Hasenhüttl  1967-08-09         1967-08-09   52
# 17                Klopp  1967-06-16         1967-06-16   52
# 0        Benítez Maudes  1960-04-16         1960-04-16   59
# 5               Hughton  1958-12-11         1958-12-11   60
# 18                Sarri  1959-01-10         1959-01-10   60
# 15              Hodgson  1947-08-09         1947-08-09   72

# %%
plt.figure(figsize=(18,10))
#add boxplot
chart = sns.boxplot(
    data=df_age_sorted,
    x ='officialName',
    y='age',
    palette="Purples_r",
    width=0.45
)
# add swarmplot
chart=sns.swarmplot(
    y='age',
    x='officialName',
    data=df_age_sorted, 
    color='black',
    alpha=0.75,
)
# make changes to x and y labels
chart.set_xticklabels(chart.get_xticklabels(),rotation=30,horizontalalignment='right',
                      fontweight='light',
                      fontsize='x-large')
chart.axes.set_title("Distribution of Age of coaches in Premier League",
                    fontsize=20)
chart.set_xlabel("Teams", 
                fontsize=14)
chart.set_ylabel("Age",
                fontsize=14)
# Out:
# Text(0, 0.5, 'Age')

# %%
# output file name
plot_file_name="/users/poojacj/Desktop/adm_hw2/RQ3/age_distribution_boxplot.jpg"
# save as jpeg
chart.figure.savefig(plot_file_name,
                    format='jpeg',
                    dpi=100)
